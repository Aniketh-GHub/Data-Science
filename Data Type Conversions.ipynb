# %%
# Integers
a = 1
b = 2
c = 3
d = 4
e = 5
f = 10
g = 20
h = 30
i = 40
j = 50
# Floats
A = 1.1
B = 2.2
C = 3.3
D = 4.4
E = 5.5
F = 10.1
G = 20.2
H = 30.3
I = 40.4
J = 50.5
# Complex numbers
complex1 = 1 + 2j
complex2 = 2 + 3j
complex3 = 3 + 4j
complex4 = 4 + 5j
complex5 = 5 + 6j
complex6 = 6 + 7j
complex7 = 7 + 8j
complex8 = 8 + 9j
complex9 = 9 + 10j
complex10 = 10 + 11j
# Type conversions int to float
float_from_a = float(a)
float_from_b = float(b)
float_from_c = float(c)
float_from_d = float(d)
float_from_e = float(e)
float_from_f = float(f)
float_from_g = float(g)
float_from_h = float(h)
float_from_i = float(i)
float_from_j = float(j)
# Type conversions float to int
int_from_A = int(A)
int_from_B = int(B)
int_from_C = int(C)
int_from_D = int(D)
int_from_E = int(E)
int_from_F = int(F)
int_from_G = int(G)
int_from_H = int(H)
int_from_I = int(I)
int_from_J = int(J)
# Type conversions int to complex
complex_from_a = complex(a)
complex_from_b = complex(b)
complex_from_c = complex(c)
complex_from_d = complex(d)
complex_from_e = complex(e)
complex_from_f = complex(f)
complex_from_g = complex(g)
complex_from_h = complex(h)
complex_from_i = complex(i)
complex_from_j = complex(j)
# Type conversions float to complex
complex_from_A = complex(A)
complex_from_B = complex(B)
complex_from_C = complex(C)
complex_from_D = complex(D)
complex_from_E = complex(E)
complex_from_F = complex(F)
complex_from_G = complex(G)
complex_from_H = complex(H)
complex_from_I = complex(I)
complex_from_J = complex(J)
# Print values
print("Integers:")
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
print(g)
print(h)
print(i)
print(j)

print("Floats:")
print(A)
print(B)
print(C)
print(D)
print(E)
print(F)
print(G)
print(H)
print(I)
print(J)

print("Complex numbers:")
print(complex1)
print(complex2)
print(complex3)
print(complex4)
print(complex5)
print(complex6)
print(complex7)
print(complex8)
print(complex9)
print(complex10)

print("Floats from integers:")
print(float_from_a)
print(float_from_b)
print(float_from_c)
print(float_from_d)
print(float_from_e)
print(float_from_f)
print(float_from_g)
print(float_from_h)
print(float_from_i)
print(float_from_j)

print("Integers from floats:")
print(int_from_A)
print(int_from_B)
print(int_from_C)
print(int_from_D)
print(int_from_E)
print(int_from_F)
print(int_from_G)
print(int_from_H)
print(int_from_I)
print(int_from_J)

print("Complex from integers:")
print(complex_from_a)
print(complex_from_b)
print(complex_from_c)
print(complex_from_d)
print(complex_from_e)
print(complex_from_f)
print(complex_from_g)
print(complex_from_h)
print(complex_from_i)
print(complex_from_j)

print("Complex from floats:")
print(complex_from_A)
print(complex_from_B)
print(complex_from_C)
print(complex_from_D)
print(complex_from_E)
print(complex_from_F)
print(complex_from_G)
print(complex_from_H)
print(complex_from_I)
print(complex_from_J)
