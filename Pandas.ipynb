# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\aniketh\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
print(df)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#importing text files
df=pd.read_csv(r"C:\Users\aniketh\anaconda3\pkgs\urls.txt")
print(df)
# Out:
#     https://repo.anaconda.com/pkgs/main/win-64/blas-1.0-mkl.conda
# 0    https://repo.anaconda.com/pkgs/main/win-64/ca-...
# 1    https://repo.anaconda.com/pkgs/main/win-64/icc...
# 2    https://repo.anaconda.com/pkgs/msys2/win-64/ms...
# 3    https://repo.anaconda.com/pkgs/main/noarch/pyb...
# 4    https://repo.anaconda.com/pkgs/main/noarch/tzd...
# ..                                                 ...
# 494  https://repo.anaconda.com/pkgs/main/win-64/htt...
# 495  https://repo.anaconda.com/pkgs/main/win-64/cer...
# 496  https://repo.anaconda.com/pkgs/main/win-64/ca-...
# 497  https://repo.anaconda.com/pkgs/main/win-64/con...
# 498  https://repo.anaconda.com/pkgs/main/win-64/ana...
#
# [499 rows x 1 columns]

# %%
df=pd.read_excel(r"C:\Users\aniketh\Downloads\SaleData.xlsx")#single sheet
print(df)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
df=pd.read_excel(r"C:\Users\aniketh\Downloads\SaleData.xlsx",sheet_name=0)#multiple sheets
print(df)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
#importing jason file 
df=pd.read_json(r"C:\Users\aniketh\Downloads\sample1.json",typ='series')
print(df)
# Out:
# fruit    Apple
# size     Large
# color      Red
# dtype: object

# %%
#using head()
df=pd.read_csv(r"/Users/aniketh/Downloads/annual-enterprise-survey-2023-financial-year-provisional.csv")
df.head(100)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2023                     Level 1                99999
# 1   2023                     Level 1                99999
# 2   2023                     Level 1                99999
# 3   2023                     Level 1                99999
# 4   2023                     Level 1                99999
# ..   ...                         ...                  ...
# 95  2023                     Level 4                AA111
# 96  2023                     Level 4                AA111
# 97  2023                     Level 4                AA111
# 98  2023                     Level 4                AA111
# 99  2023                     Level 4                AA111
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 0                   All industries  Dollars (millions)           H01
# 1                   All industries  Dollars (millions)           H04
# ...

# %%
#using tail()
df.tail(100)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50885  2013                     Level 4                RS212
# 50886  2013                     Level 4                RS212
# 50887  2013                     Level 4                RS212
# 50888  2013                     Level 4                RS212
# 50889  2013                     Level 4                RS212
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#                                     Industry_name_NZSIOC               Units  \
# 50885  Personal Care, Funeral and Other Personal Serv...  Dollars (millions)
# ...

# %%
df.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (50985, 10)
# 50985
# 10

# %%
df.isnull()
# Out:
#         Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      False                        False                 False
# 1      False                        False                 False
# 2      False                        False                 False
# 3      False                        False                 False
# 4      False                        False                 False
# ...      ...                          ...                   ...
# 50980  False                        False                 False
# 50981  False                        False                 False
# 50982  False                        False                 False
# 50983  False                        False                 False
# 50984  False                        False                 False
#
#        Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                     False  False          False          False
# ...

# %%
df.isna().head(10)
# Out:
#     Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  False                        False                 False
# 1  False                        False                 False
# 2  False                        False                 False
# 3  False                        False                 False
# 4  False                        False                 False
# 5  False                        False                 False
# 6  False                        False                 False
# 7  False                        False                 False
# 8  False                        False                 False
# 9  False                        False                 False
#
#    Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                 False  False          False          False
# 1                 False  False          False          False
# 2                 False  False          False          False
# ...

# %%
df.isna().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
df.isna().any()
# Out:
# Year                           False
# Industry_aggregation_NZSIOC    False
# Industry_code_NZSIOC           False
# Industry_name_NZSIOC           False
# Units                          False
# Variable_code                  False
# Variable_name                  False
# Variable_category              False
# Value                          False
# Industry_code_ANZSIC06         False
# dtype: bool

# %%
#accessing single dimensions
df['Industry_code_ANZSIC06']
# Out:
# 0        ANZSIC06 divisions A-S (excluding classes K633...
# 1        ANZSIC06 divisions A-S (excluding classes K633...
# 2        ANZSIC06 divisions A-S (excluding classes K633...
# 3        ANZSIC06 divisions A-S (excluding classes K633...
# 4        ANZSIC06 divisions A-S (excluding classes K633...
#                                ...
# 50980    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50982    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50983    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50984    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# Name: Industry_code_ANZSIC06, Length: 50985, dtype: object

# %%
#accessing two dimensions
df[['Industry_name_NZSIOC','Industry_code_ANZSIC06']]
# Out:
#              Industry_name_NZSIOC  \
# 0                  All industries
# 1                  All industries
# 2                  All industries
# 3                  All industries
# 4                  All industries
# ...                           ...
# 50980  Food product manufacturing
# 50981  Food product manufacturing
# 50982  Food product manufacturing
# 50983  Food product manufacturing
# 50984  Food product manufacturing
#
#                                   Industry_code_ANZSIC06
# 0      ANZSIC06 divisions A-S (excluding classes K633...
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 2      ANZSIC06 divisions A-S (excluding classes K633...
# 3      ANZSIC06 divisions A-S (excluding classes K633...
# 4      ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                  ...
# 50980  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 50981  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# ...

# %%
df[['Industry_name_NZSIOC','Industry_code_NZSIOC','Industry_code_ANZSIC06']]
# Out:
#              Industry_name_NZSIOC Industry_code_NZSIOC  \
# 0                  All industries                99999
# 1                  All industries                99999
# 2                  All industries                99999
# 3                  All industries                99999
# 4                  All industries                99999
# ...                           ...                  ...
# 50980  Food product manufacturing                 ZZ11
# 50981  Food product manufacturing                 ZZ11
# 50982  Food product manufacturing                 ZZ11
# 50983  Food product manufacturing                 ZZ11
# 50984  Food product manufacturing                 ZZ11
#
#                                   Industry_code_ANZSIC06
# 0      ANZSIC06 divisions A-S (excluding classes K633...
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 2      ANZSIC06 divisions A-S (excluding classes K633...
# 3      ANZSIC06 divisions A-S (excluding classes K633...
# ...
